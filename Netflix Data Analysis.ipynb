# %% [markdown]
# # Netflix insights

# %% [markdown]
# <img src="assets/imgs/netflix.jpg" alt="Netflix">

# %% [markdown]
# ## Sommaire

# %% [markdown]
# - [Introduction](#introduction)
# - [Installations et imports](#installations-et-imports)
#   - [Installations des dépendences](#installations-des-dépendences)
#   - [Imports des modules](#import-des-modules)
#   - [Téléchargement des ressources](#téléchargement-des-ressources)
# - [Analyse exploratoire](#analyse-exploratoire)
#   - [3. Chargez le dataset à l’aide de **Pandas** sous le format d’un DataFrame.](#3-chargez-le-dataset-à-laide-de-pandas-sous-le-format-dun-dataframe)
#   - [4. **Affichez un aperçu du DataFrame** en affichant ses 5 premières observations et ses 5 dernières observations à l’aide de deux fonctions spécifiques de Pandas.](#4-affichez-un-aperçu-du-dataframe-en-affichant-ses-5-premières-observations-et-ses-5-dernières-observations-à-laide-de-deux-fonctions-spécifiques-de-pandas)
#   - [5. **Affichez les informations du DataFrame**, notamment le type d'index et les colonnes, les valeurs non nulles et l'utilisation de la mémoire.](#5-affichez-les-informations-du-dataframe-notamment-le-type-dindex-et-les-colonnes-les-valeurs-non-nulles-et-lutilisation-de-la-mémoire)
#   - [6. Affichez **la dimensionnalité du DataFrame**. Combien avez-vous de variables ? Combien avez-vous d’observations ?](#6-affichez-la-dimensionnalité-du-dataframe-combien-avez-vous-de-variables--combien-avez-vous-dobservations)
#   - [7. Affichez les colonnes du DataFrame.](#7-affichez-les-colonnes-du-dataframe)
#   - [8. Affichez le **type des différentes colonnes du DataFrame**. Avez-vous des données quantitatives (numériques) ? Avez-vous des données qualitatives (catégorielles) ? Si oui, lesquelles ?](#8-affichez-le-type-des-différentes-colonnes-du-dataframe-avez-vous-des-données-quantitatives-numériques--avez-vous-des-données-qualitatives-catégorielles--si-oui-lesquelles)
#   - [9. **Y a-t-il des données manquantes** ? Identifiez la proportion en pourcentage.](#9-y-a-t-il-des-données-manquantes--identifiez-la-proportion-en-pourcentage)
#   - [10. A l’aide de la librairie **Missingno**. Affichez **un graphique représentatif de la proportion** des données manquantes.](#10-a-laide-de-la-librairie-missingno-affichez-un-graphique-représentatif-de-la-proportion-des-données-manquantes)
#   - [11. Affichez **une observation aléatoire** du DataFrame.](#11-affichez-une-observation-aléatoire-du-dataframe)
#   - [12. Affichez **toutes les informations** de l'œuvre **“Catch Me If You Can”**.](#12-affichez-toutes-les-informations-de-lœuvre-catch-me-if-you-can)
#   - [13. Affichez le nom du **film le plus récent** du dataset.](#13-affichez-le-nom-du-film-le-plus-récent-du-dataset)
#   - [14. Affichez le nom de **la série la plus récente** du dataset.](#14-affichez-le-nom-de-la-série-la-plus-récente-du-dataset)
#   - [15. Modifiez la variable **date_added** de telle sorte qu’elle soit de **type DateTime**.](#15-modifiez-la-variable-date_added-de-telle-sorte-quelle-soit-de-type-datetime)
#   - [16. Modifiez la variable **duration** de telle sorte que la durée des films soit un nombre plutôt qu’une chaîne de caractères, par exemple : **160 au lieu de “160 min”**.](#16-modifiez-la-variable-duration-de-telle-sorte-que-la-durée-des-films-soit-un-nombre-plutôt-quune-chaîne-de-caractères-par-exemple--160-au-lieu-de-160-min)
#   - [17. Modifiez la variable **duration** de telle sorte que la durée des séries soit un nombre plutôt qu’une chaîne de caractères, par exemple : **2 au lieu de “2 seasons”**.](#17-modifiez-la-variable-duration-de-telle-sorte-que-la-durée-des-séries-soit-un-nombre-plutôt-quune-chaîne-de-caractères-par-exemple--2-au-lieu-de-2-seasons)
#   - [18. Modifiez la variable **listed_in** de telle sorte que la chaîne de caractères soit un liste de chaîne de caractères, par exemple : **[“International TV Shows”, “TV Dramas”, “TV Mysteries”] au lieu de “International TV Shows, TV Dramas, TV Mysteries”**.](#18-modifiez-la-variable-listed_in-de-telle-sorte-que-la-chaîne-de-caractères-soit-un-liste-de-chaîne-de-caractères-par-exemple--international-tv-shows-tv-dramas-tv-mysteries-au-lieu-de-international-tv-shows-tv-dramas-tv-mysteries)
#   - [19. Affichez les **valeurs uniques** des variables : **type, country, release_year, rating et listed_in**.](#19-affichez-les-valeurs-uniques-des-variables--type-country-release_year-rating-et-listed_in)
#     - [`type`](#type)
#     - [`country`](#country)
#     - [`release_year`](#release_year)
#     - [`rating`](#rating)
#     - [`listed_in`](#listed_in)
#   - [20.Voyez-vous un **“director”** ayant produit **plus d’une œuvre** ?](#20voyez-vous-un-director-ayant-produit-plus-dune-œuvre)
#   - [21. Quelle est l’année avec **le plus de films ajoutés au catalogue de Netflix** ?](#21-quelle-est-lannée-avec-le-plus-de-films-ajoutés-au-catalogue-de-netflix)
#   - [22.Quelle est l’année avec **le plus de séries ajoutées au catalogue de Netflix** ?](#22quelle-est-lannée-avec-le-plus-de-séries-ajoutées-au-catalogue-de-netflix)
#   - [23. **Visualisez vos données à l’aide des différentes librairies de Matplotlib, Seaborn ou Plotly**](#23-visualisez-vos-données-à-laide-des-différentes-librairies-de-matplotlib-seaborn-ou-plotly)
#     - [a. La répartition du type d'oeuvres du dataset](#a-la-répartition-du-type-doeuvres-du-dataset)
#     - [b. La répartition des oeuvres en fonction des pays du dataset](#b-la-répartition-des-oeuvres-en-fonction-des-pays-du-dataset)
#     - [c. La répartition des années du dataset](#c-la-répartition-des-années-du-dataset)
#     - [d. La répartition des ratings du dataset](#d-la-répartition-des-ratings-du-dataset)
#     - [e. La répartition de la durée des films du dataset](#e-la-répartition-de-la-durée-des-films-du-dataset)
#     - [f. La répartition de la durée des séries du dataset](#f-la-répartition-de-la-durée-des-séries-du-dataset)
#     - [g. La répartition des genres d'œuvres du dataset](#g-la-répartition-des-genres-dœuvres-du-dataset)
#     - [h. Le top 5 des séries les plus longues](#h-le-top-5-des-séries-les-plus-longues)
#     - [i. Le top 5 des films les plus longs](#i-le-top-5-des-films-les-plus-longs)
#     - [j. La répartition des “directors” des œuvres françaises](#j-la-répartition-des-directors-des-œuvres-françaises)
#     - [k. La répartition des œuvres en fonction de la date d’ajout au catalogue.](#k-la-répartition-des-œuvres-en-fonction-de-la-date-dajout-au-catalogue)
#     - [l. Tout autre graphe **pertinent** pour vous.](#l-tout-autre-graphe-pertinent-pour-vous)
#       - [Nuage de mots des descriptions](#nuage-de-mots-des-descriptions)
#     - [24.Prenez soin d’**observer et analyser** tous vos graphiques. **Que pouvez-vous dire sur vos données** ?](#24prenez-soin-dobserver-et-analyser-tous-vos-graphiques-que-pouvez-vous-dire-sur-vos-données)

# %% [markdown]
# ## Introduction

# %% [markdown]
# Dans ce notebook, nous allons plonger dans les données de Netflix pour effectuer une analyse approfondie. Nous allons examiner divers aspects du contenu, y compris la répartition des types d'œuvres, les pays de production les plus courants, les années de sortie, les ratings, les durées des films et des séries, les genres d'œuvres et bien plus encore.
#
# Nous utiliserons des techniques de manipulation de données et de visualisation avec Python, en utilisant principalement les bibliothèques pandas et matplotlib. Notre objectif est de découvrir des insights intéressants sur le contenu de Netflix et de présenter nos résultats de manière claire et informative.

# %% [markdown]
# ## Installations et imports

# %% [markdown]
# <img src="assets/imgs/matrix.webp" alt="pip install">

# %% [markdown]
# ### Installations des dépendences

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import des modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
from numpy import nan

import missingno as msno
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# ### Téléchargement des ressources

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\chris\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\chris\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Analyse exploratoire

# %% [markdown]
# <img src="assets/imgs/eda.webp" alt="Exploratory Data Analysis">

# %% [markdown]
# Dans cette partie nous allons répondre aux questions posées ...

# %% [markdown]
# ### 3. Chargez le dataset à l’aide de **Pandas** sous le format d’un DataFrame.

# %%
df = pd.read_csv('netflix_titles.csv')

# %% [markdown]
# ### 4. **Affichez un aperçu du DataFrame** en affichant ses 5 premières observations et ses 5 dernières observations à l’aide de deux fonctions spécifiques de Pandas.

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# ### 5. **Affichez les informations du DataFrame**, notamment le type d'index et les colonnes, les valeurs non nulles et l'utilisation de la mémoire.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### 6. Affichez **la dimensionnalité du DataFrame**. Combien avez-vous de variables ? Combien avez-vous d’observations ?

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# Nous avons **12 variables** et **8807 observations**

# %% [markdown]
# ### 7. Affichez les colonnes du DataFrame.

# %%
print(*df.columns, sep="\n")
# Out:
# show_id
# type
# title
# director
# cast
# country
# date_added
# release_year
# rating
# duration
# listed_in
# description

# %% [markdown]
# ### 8. Affichez le **type des différentes colonnes du DataFrame**. Avez-vous des données quantitatives (numériques) ? Avez-vous des données qualitatives (catégorielles) ? Si oui, lesquelles ?

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# - Quantitatives (numériques)
#   - `duration`
#   - `date_added`
#   - `release_year`
# - Qualitatives (catégorielles)
#   - `show_id`
#   - `type`
#   - `title`
#   - `director`
#   - `cast`
#   - `country`
#   - `rating`
#   - `listed_in`
#   - `description`

# %% [markdown]
# ### 9. **Y a-t-il des données manquantes** ? Identifiez la proportion en pourcentage.

# %%
len(df)
# Out:
# 8807

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
round(df.isnull().sum() / df.shape[0] * 100, 2)
# Out:
# show_id          0.00
# type             0.00
# title            0.00
# director        29.91
# cast             9.37
# country          9.44
# date_added       0.11
# release_year     0.00
# rating           0.05
# duration         0.03
# listed_in        0.00
# description      0.00
# dtype: float64

# %% [markdown]
# Il manque des valeurs dans un certain nombre de colonnes :
# - `director` : 2634/8807 - 29.91%
# - `cast` : 825/8807 - 9.37%
# - `country` : 831/8807 - 9.44%
# - `date_added` : 10/8807 - 0.11%
# - `rating` : 4/8807 - 0.05%
# - `duration` : 3/8807 - 0.03%

# %% [markdown]
# ### 10. A l’aide de la librairie **Missingno**. Affichez **un graphique représentatif de la proportion** des données manquantes.

# %%
msno.bar(df)
plt.title("Proportion et nombre de valeurs non nulles par colonne", fontsize = 20)
plt.show()

# %% [markdown]
# ### 11. Affichez **une observation aléatoire** du DataFrame.

# %%
df.sample(1)
# Out:
#     show_id     type             title director cast        country  \
# 900    s901  TV Show  Money, Explained      NaN  NaN  United States
#
#        date_added  release_year rating  duration   listed_in  \
# 900  May 11, 2021          2021  TV-14  1 Season  Docuseries
#
#                                            description
# 900  We spend it, borrow it and save it. Now let's ...

# %% [markdown]
# ### 12. Affichez **toutes les informations** de l'œuvre **“Catch Me If You Can”**.

# %%
df[df["title"] == "Catch Me If You Can"]
# Out:
#     show_id   type                title          director  \
# 329    s330  Movie  Catch Me If You Can  Steven Spielberg
#
#                                                   cast                country  \
# 329  Leonardo DiCaprio, Tom Hanks, Christopher Walk...  United States, Canada
#
#          date_added  release_year rating duration listed_in  \
# 329  August 1, 2021          2002  PG-13  142 min    Dramas
#
#                                            description
# 329  An FBI agent makes it his mission to put cunni...

# %% [markdown]
# ### 13. Affichez le nom du **film le plus récent** du dataset.

# %%
# On transforme la colonne date_added en datetime pour pouvoir trier par date
df["date_added"] = pd.to_datetime(df["date_added"], format="mixed")

# %%
# On isole les films
df_movies = df[df["type"] == "Movie"]

# %%
# On récupère le titre du film le plus récent
df_movies.sort_values(by='date_added').tail(1)[["title", "date_added"]]
# Out:
#                   title date_added
# 0  Dick Johnson Is Dead 2021-09-25

# %% [markdown]
# Le film le plus récent est **Dick Johnson Is Dead**.

# %% [markdown]
# ### 14. Affichez le nom de **la série la plus récente** du dataset.

# %%
# On isole les séries
df_tv_shows = df[df["type"] == "TV Show"]

# %%
# On récupère le titre de la série la plus récente
df_tv_shows.sort_values(by='date_added').tail(1)[["title", "date_added"]]
# Out:
#                              title date_added
# 8182  The Adventures of Figaro Pho        NaT

# %% [markdown]
# Il n'y a pas de date d'ajout, donc il faut enlever les NaT (Not a Time) avant de récupérer la plus récente

# %%
df_tv_shows["date_added"].isna().sum()
# Out:
# 10

# %%
# On récupère le titre de la série la plus récente
df_tv_shows.dropna(subset=["date_added"]).sort_values(by='date_added').tail(1)[["title", "date_added"]]
# Out:
#            title date_added
# 1  Blood & Water 2021-09-24

# %% [markdown]
# La série la plus récente est **Blood & Water**.

# %% [markdown]
# ### 15. Modifiez la variable **date_added** de telle sorte qu’elle soit de **type DateTime**.

# %% [markdown]
# Déja fait a la question 13

# %%
# On vérifie le type
print("Type de 'date_added' :", df["date_added"].dtype)
# Out:
# Type de 'date_added' : datetime64[ns]

# %% [markdown]
# ### 16. Modifiez la variable **duration** de telle sorte que la durée des films soit un nombre plutôt qu’une chaîne de caractères, par exemple : **160 au lieu de “160 min”**.

# %%
# On extrait la duree
df["duration"] = df["duration"].str.extract(r"(\d+)")

# On transforme toutes les durées en valeur numerique
df["duration"] = pd.to_numeric(df["duration"])

# On vérifie
print("Type de la colonne : ", df["duration"].dtype)
df.head()
# Out:
# Type de la colonne :  float64
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating  duration  \
# 0 2021-09-25          2020  PG-13      90.0
# 1 2021-09-24          2021  TV-MA       2.0
# ...

# %% [markdown]
# ### 17. Modifiez la variable **duration** de telle sorte que la durée des séries soit un nombre plutôt qu’une chaîne de caractères, par exemple : **2 au lieu de “2 seasons”**.

# %% [markdown]
# Déja fait dans la question 16.

# %% [markdown]
# ### 18. Modifiez la variable **listed_in** de telle sorte que la chaîne de caractères soit un liste de chaîne de caractères, par exemple : **[“International TV Shows”, “TV Dramas”, “TV Mysteries”] au lieu de “International TV Shows, TV Dramas, TV Mysteries”**.

# %%
df["listed_in"] = df["listed_in"].str.split(", ")

# %%
# On vérifie
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating  duration  \
# 0 2021-09-25          2020  PG-13      90.0
# 1 2021-09-24          2021  TV-MA       2.0
# 2 2021-09-24          2021  TV-MA       1.0
# ...

# %% [markdown]
# ### 19. Affichez les **valeurs uniques** des variables : **type, country, release_year, rating et listed_in**.

# %% [markdown]
# #### `type`

# %%
print(*df["type"].unique(), sep="\n")
# Out:
# Movie
# TV Show

# %% [markdown]
# #### `country`

# %%
print(*df["country"].unique(), sep="\n")
# Out:
# United States
# South Africa
# nan
# India
# United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia
# United Kingdom
# Germany, Czech Republic
# Mexico
# Turkey
# Australia
# United States, India, France
# Finland
# China, Canada, United States
# South Africa, United States, Japan
# Nigeria
# Japan
# Spain, United States
# France
# Belgium
# United Kingdom, United States
# United States, United Kingdom
# France, United States
# South Korea
# Spain
# United States, Singapore
# United Kingdom, Australia, France
# United Kingdom, Australia, France, United States
# United States, Canada
# Germany, United States
# South Africa, United States
# United States, Mexico
# United States, Italy, France, Japan
# United States, Italy, Romania, United Kingdom
# Australia, United States
# Argentina, Venezuela
# United States, United Kingdom, Canada
# China, Hong Kong
# Russia
# Canada
# Hong Kong
# United States, China, Hong Kong
# Italy, United States
# United States, Germany
# ...

# %% [markdown]
# Il y a des lignes avec plusieurs pays, donc on les sépare avant d'afficher les valeurs uniques

# %%
print(*df["country"].str.split(", ").explode().unique(), sep="\n")
# Out:
# United States
# South Africa
# nan
# India
# Ghana
# Burkina Faso
# United Kingdom
# Germany
# Ethiopia
# Czech Republic
# Mexico
# Turkey
# Australia
# France
# Finland
# China
# Canada
# Japan
# Nigeria
# Spain
# Belgium
# South Korea
# Singapore
# Italy
# Romania
# Argentina
# Venezuela
# Hong Kong
# Russia
#
# Ireland
# Nepal
# New Zealand
# Brazil
# Greece
# Jordan
# Colombia
# Switzerland
# Israel
# Taiwan
# Bulgaria
# Algeria
# Poland
# Saudi Arabia
# Thailand
# Indonesia
# Egypt
# Denmark
# Kuwait
# Netherlands
# Malaysia
# Vietnam
# Hungary
# Sweden
# Lebanon
# Syria
# Philippines
# Iceland
# United Arab Emirates
# Norway
# Qatar
# Mauritius
# Austria
# Cameroon
# Palestine
# Uruguay
# United Kingdom,
# Kenya
# Chile
# Luxembourg
# Cambodia
# Bangladesh
# Portugal
# Cayman Islands
# Senegal
# Serbia
# Malta
# Namibia
# Angola
# Peru
# Mozambique
# Cambodia,
# Belarus
# Zimbabwe
# Puerto Rico
# Pakistan
# Cyprus
# Guatemala
# Iraq
# Malawi
# Paraguay
# Croatia
# Iran
# ...

# %% [markdown]
# #### `release_year`

# %%
print(*df["release_year"].unique(), sep="\n")
# Out:
# 2020
# 2021
# 1993
# 2018
# 1996
# 1998
# 1997
# 2010
# 2013
# 2017
# 1975
# 1978
# 1983
# 1987
# 2012
# 2001
# 2014
# 2002
# 2003
# 2004
# 2011
# 2008
# 2009
# 2007
# 2005
# 2006
# 1994
# 2015
# 2019
# 2016
# 1982
# 1989
# 1990
# 1991
# 1999
# 1986
# 1992
# 1984
# 1980
# 1961
# 2000
# 1995
# 1985
# 1976
# 1959
# 1988
# 1981
# 1972
# 1964
# 1945
# 1954
# 1979
# 1958
# 1956
# 1963
# 1970
# 1973
# 1925
# 1974
# 1960
# 1966
# 1971
# 1962
# 1969
# 1977
# 1967
# 1968
# 1965
# 1946
# 1942
# 1955
# 1944
# 1947
# 1943

# %% [markdown]
# #### `rating`

# %%
print(*df["rating"].unique(), sep="\n")
# Out:
# PG-13
# TV-MA
# PG
# TV-14
# TV-PG
# TV-Y
# TV-Y7
# R
# TV-G
# G
# NC-17
# 74 min
# 84 min
# 66 min
# NR
# nan
# TV-Y7-FV
# UR

# %% [markdown]
# Il y a des durées dans les ratings, il faut corriger ca !

# %%
df[df["rating"].isin(["74 min", "84 min", "66 min"])]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating  duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min       NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min       NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min       NaN
#
#      listed_in                                        description
# 5541  [Movies]  Louis C.K. muses on religion, eternal love, gi...
# 5794  [Movies]  Emmy-winning comedy writer Louis C.K. brings h...
# 5813  [Movies]  The comic puts his trademark hilarious/thought...

# %%
# On remet les durées
df.loc[df["show_id"] == "s5542", "duration"] = 74
df.loc[df["show_id"] == "s5795", "duration"] = 84
df.loc[df["show_id"] == "s5814", "duration"] = 66

# On enleve les ratings
df.loc[df["show_id"] == "s5542", "rating"] = nan
df.loc[df["show_id"] == "s5795", "rating"] = nan
df.loc[df["show_id"] == "s5814", "rating"] = nan

# On vérifie
print(*df["rating"].unique(), sep="\n")
# Out:
# PG-13
# TV-MA
# PG
# TV-14
# TV-PG
# TV-Y
# TV-Y7
# R
# TV-G
# G
# NC-17
# nan
# NR
# TV-Y7-FV
# UR

# %% [markdown]
# #### `listed_in`

# %%
print(*df["listed_in"].explode().unique(), sep="\n")
# Out:
# Documentaries
# International TV Shows
# TV Dramas
# TV Mysteries
# Crime TV Shows
# TV Action & Adventure
# Docuseries
# Reality TV
# Romantic TV Shows
# TV Comedies
# TV Horror
# Children & Family Movies
# Dramas
# Independent Movies
# International Movies
# British TV Shows
# Comedies
# Spanish-Language TV Shows
# Thrillers
# Romantic Movies
# Music & Musicals
# Horror Movies
# Sci-Fi & Fantasy
# TV Thrillers
# Kids' TV
# Action & Adventure
# TV Sci-Fi & Fantasy
# Classic Movies
# Anime Features
# Sports Movies
# Anime Series
# Korean TV Shows
# Science & Nature TV
# Teen TV Shows
# Cult Movies
# TV Shows
# Faith & Spirituality
# LGBTQ Movies
# Stand-Up Comedy
# Movies
# Stand-Up Comedy & Talk Shows
# Classic & Cult TV

# %% [markdown]
# ### 20.Voyez-vous un **“director”** ayant produit **plus d’une œuvre** ?

# %%
director_counts = df["director"].str.split(", ").explode().value_counts()
director_counts[director_counts > 1]
# Out:
# director
# Rajiv Chilaka              22
# Jan Suter                  21
# Raúl Campos                19
# Suhas Kadav                16
# Marcus Raboy               16
#                            ..
# Jung-ah Im                  2
# Saratswadee Wongsomphet     2
# Susannah Ward               2
# Malik Nejer                 2
# Aaron Moorhead              2
# Name: count, Length: 1023, dtype: int64

# %% [markdown]
# Oui, il y a 1023 directors qui ont produit plus d'une oeuvre

# %% [markdown]
# ### 21. Quelle est l’année avec **le plus de films ajoutés au catalogue de Netflix** ?

# %%
# On isole les années d'ajout dans une nouvelle colonne
df["year_added"] = df["date_added"].dt.year

# On isole les films
df_movies = df[df["type"] == "Movie"]

# On récupère l'année qui a le plus d'occurences
df_movies["year_added"].value_counts().head(1)
# Out:
# year_added
# 2019.0    1424
# Name: count, dtype: int64

# %% [markdown]
# L'année 2019 est l'année avec le plus de films ajoutés au catalogue Netflix

# %% [markdown]
# ### 22.Quelle est l’année avec **le plus de séries ajoutées au catalogue de Netflix** ?

# %%
# On isole les séries
df_tv_shows = df[df["type"] == "TV Show"]

# On récupère l'année qui a le plus d'occurence
df_tv_shows["year_added"].value_counts().head(1)
# Out:
# year_added
# 2020.0    595
# Name: count, dtype: int64

# %% [markdown]
# L'année 2020 est l'année avec le plus de séries ajoutés au catalogue Netflix

# %% [markdown]
# ### 23. **Visualisez vos données à l’aide des différentes librairies de Matplotlib, Seaborn ou Plotly**

# %% [markdown]
# #### a. La répartition du type d'oeuvres du dataset

# %%
plt.pie(x=df["type"].value_counts(), labels=df["type"].unique(), autopct="%.2f%%")
plt.legend(df["type"].unique())
plt.title("Répartition du type d'oeuvres")
plt.show()

# %% [markdown]
# On peut observer qu'il y a **un peu plus de 2x plus** (2.29 x) de films que de séries dans le dataset

# %% [markdown]
# #### b. La répartition des oeuvres en fonction des pays du dataset

# %%
# On regroupe par pays
countries_count = df["country"].str.split(", ").explode().value_counts()

# On récupère le top 20 des pays (pour la lisibilité)
top_20_countries = countries_count.head(20)

# On affiche
plt.figure(figsize=(24, 6))
ax = plt.gca()
bars = plt.bar(top_20_countries.index, top_20_countries)

for bar in bars:
    height = bar.get_height()
    ax.annotate(height,
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # décalage du texte par rapport à la barre
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel("Pays")
plt.ylabel("Nombre d'oeuvres")
plt.title("Répartition du nombre d'oeuvres par pays")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# On voit que **les Etats Unis on produit plus la majorité des films** (plus de 3500 sur 8807), suivi par l'Inde (un peu plus de 1000).

# %%
# On affiche
plt.figure(figsize=(20, 10))
plt.pie(x=countries_count, labels=countries_count.index, autopct="%.2f%%")
plt.title("Répartition des oeuvres en fonction du pays")

plt.show()

# %% [markdown]
# Le graphique n'est pas tres lisible sur la partie en bas a droite, mais on voit bien que plus d'un tiers des films ont été produits aus Etats Unis, suivi par l'Inde et le Royaume Unis. Plus de 50% du contenu est proposé par ces 3 pays dont plus du tiers (36.84%) pour les Etats Unis.

# %%
plt.figure(figsize=(25, 10))
plt.yscale("log")  # Echelle logarihmique (pour la lisibilité)
plt.bar(countries_count.index, countries_count)
plt.title("Répartition des oeuvres en fonction du pays")
plt.xticks(rotation=90)
plt.xlabel("Pays")
plt.ylabel("Echelle logatithme des durées")
plt.show()

# %% [markdown]
# On constate la même chose ...

# %% [markdown]
# #### c. La répartition des années du dataset

# %%
# On récupère les années de sortie
release_year_counts = df["release_year"].value_counts()

# On affiche
plt.figure(figsize=(20, 10))
plt.yscale("log")  # Echelle logarithmique (pour la lisibilité)
plt.bar(release_year_counts.index, release_year_counts)
plt.xlabel("Année de sortie")
plt.ylabel("Echelle logarithmique du nombre d'oeuvres")
plt.title("Répartition du nombre d'oeuvres par année de sortie")
plt.xticks(release_year_counts.index, rotation=60)

plt.show()

# %% [markdown]
# On remarque qu'il y a une **majoritée d'oeuvres qui sont sorties autours de l'année 2018**.
#
# Ceci s'explique en partie car **Netflix a considérablement augmenté son budget de production et de distribution de contenu original au cours de cette période.**

# %% [markdown]
# #### d. La répartition des ratings du dataset

# %%
df["rating"].isna().sum()
# Out:
# 7

# %%
# On remplace les NaN par "Unknown"
df["rating"] = df["rating"].fillna("Unknown")

# %%
# On récupère les ratings
rating_counts = df["rating"].value_counts()

ax = plt.gca()
# On affiche
bars = plt.bar(rating_counts.index, rating_counts)

for bar in bars:
    height = bar.get_height()
    ax.annotate(height,
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # décalage du texte par rapport à la barre
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel("Ratings")
plt.ylabel("Nombre d'oeuvres")
plt.title("Répartition du nombre d'oeuvres par rating")
plt.xticks(rotation=45, ha="right")

plt.show()

# %%
threshold = 0.01  # Par exemple, 1%

# Calculer le pourcentage de chaque catégorie
percentage = rating_counts / rating_counts.sum()

# Créer une nouvelle série où les petites catégories sont regroupées en 'Autres'
mask = percentage > threshold
rating_counts_grouped = rating_counts[mask]
rating_counts_grouped['Autres'] = rating_counts[~mask].sum()

# Afficher le graphique en camembert
plt.figure(figsize=(20, 10))
plt.pie(x=rating_counts_grouped, labels=rating_counts_grouped.index, autopct="%.2f%%")
plt.title("Répartition du nombre d'oeuvres par rating")
plt.show()

# %% [markdown]
# La **majorité des programmes proposés sur la plateforme sont en TV-MA**, un contenu qui n'est pas approprié aux moins de 17 ans, en raison de violence et de langage particulièrement grossier.
#
# **Suivi par TV-14**, un contenu qui n'est pas approprié aux moins de 14 ans pour les mêmes raisons.
#
# Lui même **suivi par TV-PG**, qui contiennent des éléments innapropriés pour les jeunes enfants.
#
# Lui même **suivi par le R**, qui signifie que les moins de 17 ans doivent être accompagné d'un adulte.
#
# Donc **une grande majorité du contenu de Netflix est violent,grossier ou inadapté à un jeune public.**
#
# **Plus 75% du contenu de la plateforme est innaproprié pour les enfants.**

# %% [markdown]
# #### e. La répartition de la durée des films du dataset

# %%
# On récupère les durées des films
movie_durations = df_movies["duration"].value_counts()

# On affiche
plt.figure(figsize=(24,6))
plt.bar(movie_durations.index, movie_durations)
plt.xlabel("Durée (en minutes)")
plt.ylabel("Nombre de films")
plt.title("Répartition des films par durée")
plt.show()

# %% [markdown]
# On remarque que la **majorité des films ont une durée entre 75 et 125 minutes**, soit entre 1h15 et 2h environ.

# %% [markdown]
# #### f. La répartition de la durée des séries du dataset

# %%
# On récupère les durées des films
tv_shows = df_tv_shows["duration"].value_counts()

# On affiche
ax = plt.gca()
bars = plt.bar(tv_shows.index, tv_shows)
for bar in bars:
    height = bar.get_height()
    ax.annotate(height,
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # décalage du texte par rapport à la barre
                textcoords="offset points",
                ha='center', va='bottom')

plt.xticks(tv_shows.index)
plt.xlabel("Durée (en saisons)")
plt.ylabel("Nombre de séries")
plt.title("Répartition des séries par durée")
plt.show()

# %% [markdown]
# On remarque que **la majorité des séries ne contiennent qu'une seule saison**.
#
# Cela peut s'expliquer par le fait que **Netflix produit lui même la majorité de son contenu, et donc ne fais pas de suite si la saison une n'a pas fonctionnée.**

# %% [markdown]
# #### g. La répartition des genres d'œuvres du dataset

# %%
genre_counts = df["listed_in"].explode().str.strip().value_counts()

plt.figure(figsize=(24, 6))
ax = plt.gca()
bars = plt.bar(genre_counts.index, genre_counts)
for bar in bars:
    height = bar.get_height()
    ax.annotate(height,
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # décalage du texte par rapport à la barre
                textcoords="offset points",
                ha='center', va='bottom')
plt.xlabel("Genre d'oeuvres")
plt.ylabel("Nombre d'oeuvres")
plt.title("Répartition des oeuvres par genre")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# On remarque que la **majorité des films sont des films internationaux, suivi des drames et des comédies.**

# %% [markdown]
# #### h. Le top 5 des séries les plus longues

# %%
# On récupère le top 5 des séries les plus longues
top_5_longest_tv_shows = df_tv_shows.sort_values(by="duration", ascending=False).head(5)

# On affiche
ax = plt.gca()
bars = plt.bar(top_5_longest_tv_shows["title"], top_5_longest_tv_shows["duration"])
for bar in bars:
    height = bar.get_height()
    ax.annotate(int(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # décalage du texte par rapport à la barre
                textcoords="offset points",
                ha='center', va='bottom')
plt.xlabel("Titre de la série")
plt.ylabel("Durée de la série (en saison)")
plt.title("Top 5 des séries les plus longues")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# La série la plus longue de la plateforme est **Grey's Anatomy** avec **17 saisons.**

# %% [markdown]
# #### i. Le top 5 des films les plus longs

# %%
# On récupère le top 5 des films les plus longs
top_5_longest_movies = df_movies.sort_values(by="duration", ascending=False).head(5)

ax = plt.gca()
bars = plt.bar(top_5_longest_movies["title"], top_5_longest_movies["duration"])
for bar in bars:
    height = bar.get_height()
    ax.annotate(int(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # décalage du texte par rapport à la barre
                textcoords="offset points",
                ha='center', va='bottom')
plt.xlabel("Titre des films")
plt.ylabel("Durée des films (en minutes)")
plt.title("Top 5 des films les plus longs")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# Le **film le plus long** présent sur la plateforme est **Black Mirror: Bandersnatch avec plus de 300 minutes (5 heures).**
#
# Il s'agit en réalité d'un **film interractif contenant plus de 5 heures de séquences filmées.**
#
# Cependant, **un seul visionnage ne dure pas 5 heures.**
#
# **La durée de l'expérience dépend des choix faits tout au long du film par le spectateur** et **la durée moyenne d'une experience est d'une heure et demi.**
#
# Le film **Headspace : Unwind Your Mind** possède les même caractéristiques, il s'agit également d'un **film interractif**, expliquant sa longue durée.
#
# Si l'on considère ces deux premiers films comme n'étant pas des films "classiques", et qu'on décide de les placer dans une catégorie singulière "films interractifs", on peut alors conclure que **le film à la durée la plus longue présent sur la plateforme en 2021 est The School of Mischief**, film égyptien de 1973 d'une **durée de 4h13.**

# %% [markdown]
# #### j. La répartition des “directors” des œuvres françaises

# %%
# On récupère les diretors francais
french_director_counts = df.loc[df["country"] == "France", "director"].str.split(", ").explode().value_counts()

# On affiche
plt.figure(figsize=(24, 6))
plt.bar(french_director_counts.index, french_director_counts)
plt.xlabel("Réalisateurs")
plt.ylabel("Nombre d'oeuvres")
plt.title("Répartition du nombre d'oeuvres des réalisateurs français")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# On remarque qu'il y a **seulement 2 francais** qui ont réalisé plusieurs oeuvres, **Thierry Donard avec 5 oeuvres** et **Florent Bodin avec 3 oeuvres.**

# %% [markdown]
# #### k. La répartition des œuvres en fonction de la date d’ajout au catalogue.

# %%
# On récupère les années d'ajout (pour la lisibilité du graphique)
year_added_counts = df["year_added"].value_counts()

# On affiche
ax = plt.gca()
bars = plt.bar(year_added_counts.index, year_added_counts)
for bar in bars:
    height = bar.get_height()
    ax.annotate(height,
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # décalage du texte par rapport à la barre
                textcoords="offset points",
                ha='center', va='bottom')

plt.xlabel("Année d'ajout")
plt.ylabel("Nombre d'oeuvres")
plt.title("Répartition du nombre d'oeuvres par année d'ajout au catalogue")
plt.show()

# %% [markdown]
# On remarque une **augmentation significative des publications sur la plateforme entre 2018 et 2021** avec un **pic en 2019.**
#
# Ceci s'explique en partie (comme pour le graph sur La répartition des années du dataset), car **Netflix a considérablement augmenté son budget de production et de distribution de contenu original au cours de cette période.**

# %% [markdown]
# #### l. Tout autre graphe **pertinent** pour vous.

# %% [markdown]
# ##### Un peu de NLP (**N**atural **L**angage **P**rocessing) ...

# %%
# On récupère les stop words
stop_words = set(stopwords.words('english'))

# %% [markdown]
# ###### Nuage de mots des titres

# %%
# On extrait le texte de la description
title_text = " ".join(df["title"].str.lower())

# On tokenize
title_tokens = word_tokenize(title_text)

# On filtre en retirant les stop words et la ponctuation
title_filtered_text = [word for word in title_tokens if word.isalpha() and word not in stop_words]

# %%
# On calcule la fréquence de distibution des mots
title_word_freq = nltk.FreqDist(title_filtered_text)

# On récupère la distribution des 20 mots les plus fréquents
title_top_20 = title_word_freq.most_common(20)
title_top_20_dict = dict(title_top_20)

# On l'affiche la distribution des 20 mots les plus fréquents
plt.figure(figsize=(24, 6))
ax = plt.gca()
bars = plt.bar(title_top_20_dict.keys(), title_top_20_dict.values())
for bar in bars:
    height = bar.get_height()
    ax.annotate(height,
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # décalage du texte par rapport à la barre
                textcoords="offset points",
                ha='center', va='bottom')
plt.xlabel("Mots")
plt.ylabel("Fréquence")
plt.title("Top 20 des mots les plus fréquents dans les titres")
plt.show()

# %%
# On crée un nuage de mots
wordcloud = WordCloud(width=800, height=200, background_color='white').generate_from_frequencies(title_word_freq)

# On l'affiche
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# On remarque que le mot le plus présent dans les titres est **"love"** (plus du double des mots suivants). Ce qui nous suggère que le sujet principal des films est l'amour.

# %% [markdown]
# ###### Nuage de mots des descriptions

# %%
# On extrait le texte de la description
description_text = " ".join(df["description"].str.lower())


# On tokenize
description_tokens = word_tokenize(description_text)

# On filtre en retirant les stop words et la ponctuation
description_filtered_text = [word for word in description_tokens if word.isalpha() and word not in stop_words]

# %%
# On calcule la fréquence de distibution des mots
description_word_freq = nltk.FreqDist(description_filtered_text)

# On récupère la distribution des 20 mots les plus fréquents
description_top_20 = description_word_freq.most_common(20)
description_top_20_dict = dict(description_top_20)

# On l'affiche la distribution des 20 mots les plus fréquents
plt.figure(figsize=(24, 6))
ax = plt.gca()
bars = plt.bar(description_top_20_dict.keys(), description_top_20_dict.values())
for bar in bars:
    height = bar.get_height()
    ax.annotate(height,
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # décalage du texte par rapport à la barre
                textcoords="offset points",
                ha='center', va='bottom')
plt.xlabel("Mots")
plt.ylabel("Fréquence")
plt.title("Top 20 des mots les plus fréquents dans les descriptions")
plt.show()

# %%
# On crée un nuage de mots
wordcloud = WordCloud(width=800, height=200, background_color='white').generate_from_frequencies(word_freq)

# On l'affiche
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# On observe que les **mots les plus présents** dans les descriptions sont **"life", "young", "new" et "family".**
#
# Ces mots sont souvent utilisés dans les descriptions sur Netflix pour plusieurs raisons:
#
# - **Reflète le contenu**: Ces mots peuvent refléter les thèmes communs et les sujets abordés dans les films et les séries télévisées sur Netflix. Par exemple, de nombreux spectacles peuvent tourner autour de la “vie” quotidienne, des défis de la “jeunesse”, des “nouvelles” aventures ou des dynamiques “familiales”.
#
# - **Attirer un large public**: Ces mots sont assez universels et peuvent attirer un large éventail de téléspectateurs. Par exemple, presque tout le monde peut se rapporter à des thèmes de “vie” ou de “famille”, et les mots comme “jeune” et “nouveau” peuvent susciter un sentiment d’excitation ou de nouveauté.
#
# - **Stratégies basées sur les données**: Netflix utilise des stratégies basées sur les données pour décider du contenu à produire et à promouvoir. Ils analysent les mots les plus couramment utilisés dans les titres et les descriptions pour comprendre les thèmes et les sujets qui résonnent le plus avec leur public.

# %% [markdown]
# ### 24.Prenez soin d’**observer et analyser** tous vos graphiques. **Que pouvez-vous dire sur vos données** ?

# %% [markdown]
# L'analyse approfondie des données du dataset Netflix révèle plusieurs idées significatives sur le contenu proposé sur la plateforme :
#
# - La **répartition du type d'œuvres** révèle qu'il y a **environ deux fois plus de films que de séries** dans le dataset.
# - **Le graphique de répartition par pays** montre que **plus d'un tiers des films ont été produits aux États-Unis, suivi par l'Inde et le Royaume-Uni.** Plus de **50%** du contenu est **proposé par ces trois pays** et **plus d'un tiers** (36.84%) par les **Etats Unis**.
# - La **majorité des œuvres** ont été publiées vers les **années 2018/2019**, selon la répartition des années de sortie.
# - Concernant les **ratings** (classification du contenu en fonction du public), la **majorité des programmes proposés sur la plateforme sont en TV-MA**, un **contenu inapproprié pour les moins de 17 ans** en raison de violence et de langage grossier, suivi par **TV-14**, également **inapproprié pour les moins de 14 ans** pour les mêmes raisons. Ces deux catégories sont suivies par **TV-PG**, qui contient des éléments **inappropriés pour les jeunes enfants**, et le rating **R**, indiquant que les **moins de 17 ans doivent être accompagnés** d'un adulte. Cela signifie qu'au moins **75% du contenu de la plateforme est inapproprié pour un jeune public et pour les enfants.**
# - La **durée des films** est généralement comprise entre **75 et 125 minutes**, tandis que la **majorité des séries** semblent n'avoir qu'**une seule saison**.
# - Les **genres d'œuvres** les plus courants sont les films **internationaux, les drames et les comédies.**
# - La **série les plus longues** est **Grey's Anatomy** avec **17 saisons.**
# - Le **film le plus long** présent sur la plateforme est **Black Mirror: Bandersnatch** avec **plus de 300 minutes** (5 heures). Il s'agit en réalité d'un **film interractif** contenant plus de 5 heures de séquences filmées. Cependant, **un seul visionnage ne dure pas 5 heures** et la **durée de l'expérience dépend des choix faits** tout au long du film par le spectateur. La **durée moyenne d'une experience est d'une heure et demi.** Le film **Headspace : Unwind Your Mind** possède les même caractéristiques, il s'agit également d'un **film interractif**, expliquant sa longue durée. Si l'on considère ces deux premiers films comme n'étant pas des films "classiques", et qu'on décide de les placer dans une catégorie singulière "films interractifs", on peut alors conclure que **le film à la durée la plus longue** présent sur la plateforme en 2021 est **The School of Mischief**, film égyptien de 1973 d'une durée de **4h13.**
# - **Thierry Donard** et **Florent Bodin** sont les réalisateurs français les plus présents dans le dataset avec respectivement **5 oeuvres** pour le premier et **3 oeuvres** pour le second.
# - La **répartition des œuvres en fonction de leur date d'ajout** au catalogue montre un **pic de publications en 2019**. Ceci s'explique en partie car **Netflix a considérablement augmenté son budget de production et de distribution de contenu** original au cours de cette période.
# - Enfin, le **wordcloud des descriptions** met en évidence les mots **"life", "young", "new" et "family"**, suggérant des thèmes récurrents tels que la **vie, la jeunesse, les nouveautés et la famille** dans le contenu proposé.
#
# Ces observations fournissent une vue d'ensemble complète du contenu disponible sur Netflix, mettant en lumière les tendances, les préférences des utilisateurs et les caractéristiques les plus courantes des œuvres présentes sur la plateforme. Il est également important de noter que la **majorité du contenu est inappropriée pour les enfants**, soulignant ainsi l'**importance de la supervision parentale** lors de l'utilisation de la plateforme par des enfants.
